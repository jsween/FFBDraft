# %%
import pandas as pd

# %%
wk_plyr_off = pd.read_csv("data/raw/weekly_player_stats_offense.csv")

# %%
wk_plyr_off.head()
# Out:
#    season  week  offense_snaps  offense_pct  team_offense_snaps   player_id  \
# 0    2012    12           63.0         1.00                63.0  00-0000865
# 1    2012    13           66.0         1.00                66.0  00-0000865
# 2    2012     2           12.0         0.18                67.0  00-0004541
# 3    2012     3            4.0         0.05                80.0  00-0004541
# 4    2012     4           18.0         0.26                69.0  00-0004541
#
#    birth_year  draft_year  draft_round  draft_pick  ...  career_rush_td_pct  \
# 0        1974      1998.0          2.0        30.0  ...                 NaN
# 1        1974      1998.0          2.0        30.0  ...                 NaN
# 2        1975      1999.0          7.0         7.0  ...                 NaN
# 3        1975      1999.0          7.0         7.0  ...                 NaN
# 4        1975      1999.0          7.0         7.0  ...                 NaN
#
# ...
